# %% [markdown]
# <a href="https://colab.research.google.com/github/andhepraveen2005/ML_LAB_2026-27/blob/main/ML_LAB_DAY1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/students.csv")

# %%
df.describe ()
# Out:
#        Subject_1  Subject_2  Subject_3  Subject_4  Subject_5  Total_Marks  \
# count   5.000000   5.000000   5.000000   5.000000   5.000000     5.000000
# mean   71.400000  70.400000  73.400000  77.400000  69.800000   362.400000
# std    17.812917  17.008821  18.146625  15.420765  17.253985    84.370018
# min    45.000000  52.000000  49.000000  55.000000  47.000000   248.000000
# 25%    65.000000  58.000000  62.000000  70.000000  60.000000   315.000000
# 50%    72.000000  69.000000  75.000000  80.000000  70.000000   366.000000
# 75%    85.000000  78.000000  89.000000  88.000000  81.000000   424.000000
# max    90.000000  95.000000  92.000000  94.000000  91.000000   459.000000
#
#        Percentage
# count    5.000000
# mean    72.480000
# std     16.874004
# min     49.600000
# 25%     63.000000
# 50%     73.200000
# 75%     84.800000
# max     91.800000

# %%
df.head()
# Out:
#   Student_ID   Student_Name    Semester  Subject_1  Subject_2  Subject_3  \
# 0       S001  Alice Johnson  Semester 1         85         78         92
# 1       S002      Bob Smith  Semester 1         72         69         75
# 2       S003  Charlie Brown  Semester 1         90         95         89
# 3       S004   Diana Wilson  Semester 1         65         58         62
# 4       S005    Ethan Davis  Semester 1         45         52         49
#
#    Subject_4  Subject_5  Total_Marks  Percentage Grade Result
# 0         88         81          424        84.8     A   Pass
# 1         80         70          366        73.2     B   Pass
# 2         94         91          459        91.8    A+   Pass
# 3         70         60          315        63.0     C   Pass
# 4         55         47          248        49.6     D   Fail

# %%
df.tail()
# Out:
#   Student_ID   Student_Name    Semester  Subject_1  Subject_2  Subject_3  \
# 0       S001  Alice Johnson  Semester 1         85         78         92
# 1       S002      Bob Smith  Semester 1         72         69         75
# 2       S003  Charlie Brown  Semester 1         90         95         89
# 3       S004   Diana Wilson  Semester 1         65         58         62
# 4       S005    Ethan Davis  Semester 1         45         52         49
#
#    Subject_4  Subject_5  Total_Marks  Percentage Grade Result
# 0         88         81          424        84.8     A   Pass
# 1         80         70          366        73.2     B   Pass
# 2         94         91          459        91.8    A+   Pass
# 3         70         60          315        63.0     C   Pass
# 4         55         47          248        49.6     D   Fail

# %%
df.Resultg
# Out:
# 0    Pass
# 1    Pass
# 2    Pass
# 3    Pass
# 4    Fail
# Name: Result, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student_ID    5 non-null      object
#  1   Student_Name  5 non-null      object
#  2   Semester      5 non-null      object
#  3   Subject_1     5 non-null      int64
#  4   Subject_2     5 non-null      int64
#  5   Subject_3     5 non-null      int64
#  6   Subject_4     5 non-null      int64
#  7   Subject_5     5 non-null      int64
#  8   Total_Marks   5 non-null      int64
#  9   Percentage    5 non-null      float64
#  10  Grade         5 non-null      object
#  11  Result        5 non-null      object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 612.0+ bytes

# %%
df.columns
# Out:
# Index(['Student_ID', 'Student_Name', 'Semester', 'Subject_1', 'Subject_2',
#        'Subject_3', 'Subject_4', 'Subject_5', 'Total_Marks', 'Percentage',
#        'Grade', 'Result'],
#       dtype='object')

# %%
df.Percentage
# Out:
# 0    84.8
# 1    73.2
# 2    91.8
# 3    63.0
# 4    49.6
# Name: Percentage, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.bar( df.Student_Name,df.Percentage)
# Out:
# <BarContainer object of 5 artists>
